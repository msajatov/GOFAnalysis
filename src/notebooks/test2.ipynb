# %%
import evalgof
df = evalgof.main()
#evalgof.showSideBySide(df, "cc", "nn6")
# Out:
# [u'bpt_2', u'bpt_1', u'mt_2', u'mt_1', u'jpt_2', u'njets', u'pt_1', u'nbtag', u'mjj', u'pt_2', u'met', u'm_sv', u'pt_tt', u'pt_vis', u'm_vis', u'dijetpt', u'jdeta', u'jpt_1']
#     dc_type       gof_mode conf      var       test channel  pvalue
# 180  emb_dc  results_w_emb   cc    bpt_2         KS      et   0.004
# 181  emb_dc  results_w_emb   cc    bpt_2         KS      tt   0.980
# 182  emb_dc  results_w_emb   cc    bpt_2         KS      mt   0.072
# 183  emb_dc  results_w_emb   cc    bpt_2  saturated      et   0.172
# 184  emb_dc  results_w_emb   cc    bpt_2  saturated      tt   0.992
# 185  emb_dc  results_w_emb   cc    bpt_2  saturated      mt   0.834
# 186  emb_dc  results_w_emb   cc    bpt_2         AD      et   0.010
# 187  emb_dc  results_w_emb   cc    bpt_2         AD      tt   0.976
# 188  emb_dc  results_w_emb   cc    bpt_2         AD      mt   0.078
# 189  emb_dc  results_w_emb   cc    bpt_1         KS      et   0.460
# ...
